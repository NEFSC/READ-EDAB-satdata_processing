# %%
import sys
from pathlib import Path
import xarray as xr
import os

current_path = Path.cwd()

# Search for the utilities directory
for parent in current_path.parents:
    candidate = parent / "utilities"
    if candidate.is_dir():
        sys.path.insert(0, str(parent))
        break
else:
    raise FileNotFoundError("Could not locate 'utilities' directory in parent paths.")

from utilities import date_utilities, file_utilities, calc_primprod, calc_phytosizeclass, mapping_utilities,init_notebook_environment
from utilities import get_prod_files,run_psc_pipeline,subset_dataset, parse_dataset_info,make_product_output_dir,get_dates,get_source_file_dates

env = init_notebook_environment(verbose=False)

# %%
from utilities.calc_phytosizeclass import run_psc_pipeline
run_psc_pipeline(sst_dataset="CORALSST",daterange=['19980101','19980131'])
# Out:
# /Users/kimberly.hyde/Documents/nadata/DATASETS/OCCCI/V6.0/EDAB_PRODUCTS/NES_4KM_DAILY/PSC
# 📅 Mapped 31 dates with complete product files.
# 🚀 Processing 31 dates...
# Regridding SST files to CHL grid...
# /Users/kimberly.hyde/miniconda3/envs/satprocessing/lib/python3.11/site-packages/xarray/computation/apply_ufunc.py:310: PerformanceWarning: Regridding is increasing the number of chunks by a factor of 25.0, you might want to specify sizes in `output_chunks` in the regridder call. Default behaviour is to preserve the chunk sizes from the input (900, 1800).
#   result_var = func(*data_vars)
# /Users/kimberly.hyde/miniconda3/envs/satprocessing/lib/python3.11/site-packages/dask/array/routines.py:333: PerformanceWarning: Increasing number of chunks by factor of 25
#   intermediate = blockwise(
# Writing PSC files to /Users/kimberly.hyde/Documents/nadata/DATASETS/OCCCI/V6.0/EDAB_PRODUCTS/NES_4KM_DAILY/PSC
# Subsetting to region: NES
# ...

# %%
from utilities.calc_primprod import run_pp_pipeline
run_pp_pipeline(sst_dataset="CORALSST",daterange=1998)
# Out:
# ⚠ Missing data for 19980201: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980202: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980203: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980204: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980205: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980206: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980207: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980208: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980209: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980210: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980211: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980212: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980213: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980214: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980215: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980216: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980217: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980218: CHL ✅  SST ❌  PAR ❌
# ⚠ Missing data for 19980219: CHL ✅  SST ❌  PAR ❌
# ...
