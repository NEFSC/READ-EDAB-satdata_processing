# %%
import os
import xarray as xr
from mapped_pixel_area import pixel_area

# %%
# Load your dataset (must have lat/lon as 2D arrays if irregular)
dirdata = r'/Users/kimberly.hyde/Documents/nadata/DATASETS_SOURCE/'
dirchl = os.path.join(dirdata,'OCCCI/V6.0/SOURCE_DATA/MAPPED_4KM_DAILY/CHL/')
ds = xr.open_mfdataset(os.path.join(dirchl,'*.nc'), combine='by_coords')

area_da = compute_geodesic_pixel_area(ds['lat'].values, ds['lon'].values)
area_da
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       2 dirdata = r'/Users/kimberly.hyde/Documents/nadata/DATASETS_SOURCE/'
#       3 dirchl = os.path.join(dirdata,'OCCCI/V6.0/SOURCE_DATA/MAPPED_4KM_DAILY/CHL/')
# ----> 4 ds = xr.open_mfdataset(os.path.join(dirchl,'*.nc'), combine='by_coords')
#       6 area_da = compute_geodesic_pixel_area(ds['lat'].values, ds['lon'].values)
#       7 area_da
#
# File ~/miniconda3/lib/python3.13/site-packages/xarray/backends/api.py:1635, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1632     open_ = open_dataset
#    1633     getattr_ = getattr
# -> 1635 datasets = [open_(p, **open_kwargs) for p in paths1d]
#    1636 closers = [getattr_(ds, "_close") for ds in datasets]
#    1637 if preprocess is not None:
#
# ...
